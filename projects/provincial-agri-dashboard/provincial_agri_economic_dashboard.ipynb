# %%
# Provincial Agricultural Economics Dashboard
## Tools: Python (Pandas, Matplotlib) & Looker Studio
## Data: DALRRD Abstract of Agricultural Statistics 2022-2024
##  Objective: Analyze agricultural economic perfomance across all 9 SA provinces

# %%
import pandas as pd
import matplotlib.pyplot as plt
import searborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# Load cleaned dataset
